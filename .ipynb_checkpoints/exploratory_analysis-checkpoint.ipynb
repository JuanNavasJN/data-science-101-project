# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('./pre_procesing_output.csv')

# %%
data.head()
# Out:
#    population  suicides/100kpop  gdp_for_year($)  gdp_per_capita($)  \
# 0     2709600             31.85       2156624900                796
# 1     2764300             32.46       2126000000                769
# 2     2803100             33.40       2335124988                833
# 3     2822500             18.00        709452584                251
# 4     2807300             32.56       1228071038                437
#
#    suicides_no
# 0           73
# 1           63
# 2           68
# 3           47
# 4           73

# %%
data.describe()
# Out:
#          population  suicides/100kpop  gdp_for_year($)  gdp_per_capita($)  \
# count  2.321000e+03       2321.000000     2.321000e+03        2321.000000
# mean   2.211209e+07        153.616471     4.452791e+11       16876.573460
# std    4.167543e+07        116.936498     1.453108e+12       18896.450283
# min    2.519200e+04          0.000000     4.691962e+07         251.000000
# 25%    1.996086e+06         65.910000     8.992642e+09        3450.000000
# 50%    5.360200e+06        131.900000     4.811469e+10        9378.000000
# 75%    2.056996e+07        213.220000     2.602024e+11       24874.000000
# max    3.000785e+08        639.300000     1.812071e+13      126352.000000
#
#         suicides_no
# count   2321.000000
# mean    2907.548470
# std     7077.828004
# min        0.000000
# 25%      118.000000
# 50%      565.000000
# 75%     2247.000000
# max    61420.000000

# %%
data.corr()
# Out:
#                    population  suicides/100kpop  gdp_for_year($)  \
# population           1.000000          0.077350         0.800281
# suicides/100kpop     0.077350          1.000000         0.049365
# gdp_for_year($)      0.800281          0.049365         1.000000
# gdp_per_capita($)    0.091413          0.002766         0.303126
# suicides_no          0.808095          0.343985         0.657589
#
#                    gdp_per_capita($)  suicides_no
# population                  0.091413     0.808095
# suicides/100kpop            0.002766     0.343985
# gdp_for_year($)             0.303126     0.657589
# gdp_per_capita($)           1.000000     0.093461
# suicides_no                 0.093461     1.000000

# %%
plt.plot(data['population'])
plt.rcParams["figure.figsize"] = (30, 10)
plt.show()

# %%
plt.plot(data['suicides/100kpop'])
plt.rcParams["figure.figsize"] = (30, 10)
plt.show()

# %%
plt.plot(data['suicides_no'])
plt.rcParams["figure.figsize"] = (15, 5)
plt.show()
